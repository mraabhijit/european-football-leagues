# %%
import requests
import json
import pandas as pd
import pprint
from tqdm import tqdm
import time

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("../temp/.secret/football-data.json")
headers = { 
    'X-Auth-Token': keys["X-Auth-Token"] 
}

# %%
uri = "https://api.football-data.org/v4/competitions/BL1//matches?matchday=2"
uri
# Out:
# 'https://api.football-data.org/v4/competitions/BL1//matches?matchday=2'

# %%
uri = "https://api.football-data.org/v4/competitions/PD//matches?matchday=2"
response = requests.get(uri, headers=headers)
for i, match in enumerate(response.json()['matches']):
    print(match)
# Out:
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438491, 'utcDate': '2023-08-18T17:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 89, 'name': 'RCD Mallorca', 'shortName': 'Mallorca', 'tla': 'MAL', 'crest': 'https://crests.football-data.org/89.png'}, 'awayTeam': {'id': 94, 'name': 'Villarreal CF', 'shortName': 'Villarreal', 'tla': 'VIL', 'crest': 'https://crests.football-data.org/94.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 1}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 80747, 'name': 'Javier Alberola Rojas', 'type': 'REFEREE', 'nationality': None}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438490, 'utcDate': '2023-08-18T19:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 95, 'name': 'Valencia CF', 'shortName': 'Valencia', 'tla': 'VAL', 'crest': 'https://crests.football-data.org/95.svg'}, 'awayTeam': {'id': 275, 'name': 'UD Las Palmas', 'shortName': 'Las Palmas', 'tla': 'LPA', 'crest': 'https://crests.football-data.org/275.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 215462, 'name': 'Javier Iglesias Villanueva', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438492, 'utcDate': '2023-08-19T15:00:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 92, 'name': 'Real Sociedad de Fútbol', 'shortName': 'Real Sociedad', 'tla': 'RSO', 'crest': 'https://crests.football-data.org/92.svg'}, 'awayTeam': {'id': 558, 'name': 'RC Celta de Vigo', 'shortName': 'Celta', 'tla': 'CEL', 'crest': 'https://crests.football-data.org/558.svg'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 1}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 207048, 'name': 'Miguel Ortiz Arias', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438493, 'utcDate': '2023-08-19T17:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2024-03-16T10:21:28Z', 'homeTeam': {'id': 267, 'name': 'UD Almería', 'shortName': 'Almería', 'tla': 'ALM', 'crest': 'https://crests.football-data.org/267.png'}, 'awayTeam': {'id': 86, 'name': 'Real Madrid CF', 'shortName': 'Real Madrid', 'tla': 'RMA', 'crest': 'https://crests.football-data.org/86.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 1, 'away': 3}, 'halfTime': {'home': 1, 'away': 1}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 207080, 'name': 'José Sánchez Martínez', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438485, 'utcDate': '2023-08-19T19:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 79, 'name': 'CA Osasuna', 'shortName': 'Osasuna', 'tla': 'OSA', 'crest': 'https://crests.football-data.org/79.svg'}, 'awayTeam': {'id': 77, 'name': 'Athletic Club', 'shortName': 'Athletic', 'tla': 'ATH', 'crest': 'https://crests.football-data.org/77.png'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 2}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 206223, 'name': 'José Munuera Montero', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438488, 'utcDate': '2023-08-20T17:00:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 298, 'name': 'Girona FC', 'shortName': 'Girona', 'tla': 'GIR', 'crest': 'https://crests.football-data.org/298.png'}, 'awayTeam': {'id': 82, 'name': 'Getafe CF', 'shortName': 'Getafe', 'tla': 'GET', 'crest': 'https://crests.football-data.org/82.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 3, 'away': 0}, 'halfTime': {'home': 1, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 215559, 'name': 'Jorge Figueroa Vázquez', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438487, 'utcDate': '2023-08-20T17:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 81, 'name': 'FC Barcelona', 'shortName': 'Barça', 'tla': 'FCB', 'crest': 'https://crests.football-data.org/81.svg'}, 'awayTeam': {'id': 264, 'name': 'Cádiz CF', 'shortName': 'Cádiz CF', 'tla': 'CAD', 'crest': 'https://crests.football-data.org/264.png'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 2, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 215569, 'name': 'Alejandro Muñiz Ruiz', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438484, 'utcDate': '2023-08-20T19:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 90, 'name': 'Real Betis Balompié', 'shortName': 'Real Betis', 'tla': 'BET', 'crest': 'https://crests.football-data.org/90.png'}, 'awayTeam': {'id': 78, 'name': 'Club Atlético de Madrid', 'shortName': 'Atleti', 'tla': 'ATL', 'crest': 'https://crests.football-data.org/78.svg'}, 'score': {'winner': 'DRAW', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 0}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 15628, 'name': 'Ricardo de Burgos', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438486, 'utcDate': '2023-08-21T17:00:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 263, 'name': 'Deportivo Alavés', 'shortName': 'Alavés', 'tla': 'ALA', 'crest': 'https://crests.football-data.org/263.png'}, 'awayTeam': {'id': 559, 'name': 'Sevilla FC', 'shortName': 'Sevilla FC', 'tla': 'SEV', 'crest': 'https://crests.football-data.org/559.svg'}, 'score': {'winner': 'HOME_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 4, 'away': 3}, 'halfTime': {'home': 2, 'away': 2}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 206215, 'name': 'Guillermo Cuadra Fernández', 'type': 'REFEREE', 'nationality': 'Spain'}]}
# {'area': {'id': 2224, 'name': 'Spain', 'code': 'ESP', 'flag': 'https://crests.football-data.org/760.svg'}, 'competition': {'id': 2014, 'name': 'Primera Division', 'code': 'PD', 'type': 'LEAGUE', 'emblem': 'https://crests.football-data.org/PD.png'}, 'season': {'id': 1577, 'startDate': '2023-08-13', 'endDate': '2024-05-26', 'currentMatchday': 29, 'winner': None}, 'id': 438489, 'utcDate': '2023-08-21T19:30:00Z', 'status': 'FINISHED', 'matchday': 2, 'stage': 'REGULAR_SEASON', 'group': None, 'lastUpdated': '2023-10-09T15:20:25Z', 'homeTeam': {'id': 83, 'name': 'Granada CF', 'shortName': 'Granada', 'tla': 'GRA', 'crest': 'https://crests.football-data.org/83.svg'}, 'awayTeam': {'id': 87, 'name': 'Rayo Vallecano de Madrid', 'shortName': 'Rayo Vallecano', 'tla': 'RAY', 'crest': 'https://crests.football-data.org/87.svg'}, 'score': {'winner': 'AWAY_TEAM', 'duration': 'REGULAR', 'fullTime': {'home': 0, 'away': 2}, 'halfTime': {'home': 0, 'away': 0}}, 'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'}, 'referees': [{'id': 206206, 'name': 'Pablo González Fuertes', 'type': 'REFEREE', 'nationality': 'Spain'}]}

# %%
base_url = "https://api.football-data.org/"
comp = 'v4/competitions/'
matchday = "//matches?matchday="

matchdays = {"PL": ["Premier League", 38], 
            "BL1": ["Bundesliga", 34],
            "FL1": ["Ligue 1", 38],
            "PD": ["La Liga", 38],
            "SA": ["Serie A", 38]}

match_list = {}
count = 1
for key, value in matchdays.items():
    print(f"Getting data for {value[0]}")
    match_list[value[0]] = []
    for i in range(value[1]):
        uri = base_url + comp + key + matchday + f"{i+1}"
        print(f"Getting data from {uri}")
        if count%10 == 1:
            time.sleep(60)
        try: 
            response = requests.get(uri, headers=headers)
            print(response)
            print()
            match_list[value[0]].append(response.json())
        except FileNotFoundError:
            print("matchday data not available")
        count += 1
    print()
# Out:
# Getting data for Premier League
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=1
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=2
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=3
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=4
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=5
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=6
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=7
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=8
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=9
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=10
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=11
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=12
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=13
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=14
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=15
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=16
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=17
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=18
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=19
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=20
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=21
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=22
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=23
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=24
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=25
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=26
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=27
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=28
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=29
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=30
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=31
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=32
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=33
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=34
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=35
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=36
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=37
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PL//matches?matchday=38
# <Response [200]>
#
#
# Getting data for Bundesliga
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=1
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=2
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=3
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=4
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=5
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=6
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=7
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=8
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=9
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=10
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=11
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=12
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=13
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=14
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=15
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=16
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=17
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=18
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=19
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=20
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=21
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=22
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=23
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=24
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=25
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=26
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=27
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=28
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=29
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=30
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=31
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=32
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=33
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/BL1//matches?matchday=34
# <Response [200]>
#
#
# Getting data for Ligue 1
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=1
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=2
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=3
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=4
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=5
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=6
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=7
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=8
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=9
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=10
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=11
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=12
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=13
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=14
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=15
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=16
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=17
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=18
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=19
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=20
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=21
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=22
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=23
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=24
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=25
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=26
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=27
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=28
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=29
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=30
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=31
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=32
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=33
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=34
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=35
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=36
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=37
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/FL1//matches?matchday=38
# <Response [200]>
#
#
# Getting data for La Liga
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=1
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=2
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=3
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=4
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=5
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=6
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=7
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=8
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=9
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=10
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=11
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=12
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=13
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=14
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=15
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=16
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=17
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=18
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=19
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=20
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=21
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=22
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=23
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=24
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=25
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=26
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=27
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=28
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=29
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=30
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=31
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=32
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=33
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=34
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=35
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=36
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=37
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/PD//matches?matchday=38
# <Response [200]>
#
#
# Getting data for Serie A
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=1
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=2
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=3
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=4
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=5
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=6
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=7
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=8
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=9
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=10
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=11
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=12
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=13
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=14
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=15
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=16
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=17
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=18
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=19
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=20
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=21
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=22
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=23
# <Response [500]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=24
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=25
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=26
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=27
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=28
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=29
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=30
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=31
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=32
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=33
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=34
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=35
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=36
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=37
# <Response [200]>
#
# Getting data from https://api.football-data.org/v4/competitions/SA//matches?matchday=38
# <Response [200]>

# %%
pprint.pprint(match_list['Premier League'][0])
# Out:
# {'competition': {'code': 'PL',
#                  'emblem': 'https://crests.football-data.org/PL.png',
#                  'id': 2021,
#                  'name': 'Premier League',
#                  'type': 'LEAGUE'},
#  'filters': {'matchday': '1', 'season': '2023'},
#  'matches': [{'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/65.png',
#                            'id': 65,
#                            'name': 'Manchester City FC',
#                            'shortName': 'Man City',
#                            'tla': 'MCI'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/328.png',
#                            'id': 328,
#                            'name': 'Burnley FC',
#                            'shortName': 'Burnley',
#                            'tla': 'BUR'},
#               'id': 435943,
#               'lastUpdated': '2024-03-16T10:21:28Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11585,
#                             'name': 'Craig Pawson',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 3, 'home': 0},
#                         'halfTime': {'away': 2, 'home': 0},
#                         'winner': 'AWAY_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-11T19:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/351.png',
#                            'id': 351,
#                            'name': 'Nottingham Forest FC',
#                            'shortName': 'Nottingham',
#                            'tla': 'NOT'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/57.png',
#                            'id': 57,
#                            'name': 'Arsenal FC',
#                            'shortName': 'Arsenal',
#                            'tla': 'ARS'},
#               'id': 435944,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11605,
#                             'name': 'Michael Oliver',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 2},
#                         'halfTime': {'away': 0, 'home': 2},
#                         'winner': 'HOME_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T12:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/563.png',
#                            'id': 563,
#                            'name': 'West Ham United FC',
#                            'shortName': 'West Ham',
#                            'tla': 'WHU'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/1044.png',
#                            'id': 1044,
#                            'name': 'AFC Bournemouth',
#                            'shortName': 'Bournemouth',
#                            'tla': 'BOU'},
#               'id': 435945,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11309,
#                             'name': 'Peter Bankes',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 1},
#                         'halfTime': {'away': 0, 'home': 0},
#                         'winner': 'DRAW'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T14:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/389.png',
#                            'id': 389,
#                            'name': 'Luton Town FC',
#                            'shortName': 'Luton Town',
#                            'tla': 'LUT'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/397.svg',
#                            'id': 397,
#                            'name': 'Brighton & Hove Albion FC',
#                            'shortName': 'Brighton Hove',
#                            'tla': 'BHA'},
#               'id': 435946,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11556,
#                             'name': 'David Coote',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 4},
#                         'halfTime': {'away': 0, 'home': 1},
#                         'winner': 'HOME_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T14:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/63.svg',
#                            'id': 63,
#                            'name': 'Fulham FC',
#                            'shortName': 'Fulham',
#                            'tla': 'FUL'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/62.png',
#                            'id': 62,
#                            'name': 'Everton FC',
#                            'shortName': 'Everton',
#                            'tla': 'EVE'},
#               'id': 435947,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11494,
#                             'name': 'Stuart Attwell',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 0},
#                         'halfTime': {'away': 0, 'home': 0},
#                         'winner': 'AWAY_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T14:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/354.png',
#                            'id': 354,
#                            'name': 'Crystal Palace FC',
#                            'shortName': 'Crystal Palace',
#                            'tla': 'CRY'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/356.svg',
#                            'id': 356,
#                            'name': 'Sheffield United FC',
#                            'shortName': 'Sheffield Utd',
#                            'tla': 'SHE'},
#               'id': 435948,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11327,
#                             'name': 'John Brooks',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 0},
#                         'halfTime': {'away': 0, 'home': 0},
#                         'winner': 'AWAY_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T14:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/58.png',
#                            'id': 58,
#                            'name': 'Aston Villa FC',
#                            'shortName': 'Aston Villa',
#                            'tla': 'AVL'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/67.png',
#                            'id': 67,
#                            'name': 'Newcastle United FC',
#                            'shortName': 'Newcastle',
#                            'tla': 'NEW'},
#               'id': 435949,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11423,
#                             'name': 'Andy Madley',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 5},
#                         'halfTime': {'away': 1, 'home': 2},
#                         'winner': 'HOME_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-12T16:30:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/73.svg',
#                            'id': 73,
#                            'name': 'Tottenham Hotspur FC',
#                            'shortName': 'Tottenham',
#                            'tla': 'TOT'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/402.png',
#                            'id': 402,
#                            'name': 'Brentford FC',
#                            'shortName': 'Brentford',
#                            'tla': 'BRE'},
#               'id': 435950,
#               'lastUpdated': '2023-09-19T20:20:30Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11446,
#                             'name': 'Robert Jones',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 2, 'home': 2},
#                         'halfTime': {'away': 2, 'home': 2},
#                         'winner': 'DRAW'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-13T13:00:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/64.png',
#                            'id': 64,
#                            'name': 'Liverpool FC',
#                            'shortName': 'Liverpool',
#                            'tla': 'LIV'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/61.png',
#                            'id': 61,
#                            'name': 'Chelsea FC',
#                            'shortName': 'Chelsea',
#                            'tla': 'CHE'},
#               'id': 435951,
#               'lastUpdated': '2024-03-16T10:21:28Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11580,
#                             'name': 'Anthony Taylor',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 1, 'home': 1},
#                         'halfTime': {'away': 1, 'home': 1},
#                         'winner': 'DRAW'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-13T15:30:00Z'},
#              {'area': {'code': 'ENG',
#                        'flag': 'https://crests.football-data.org/770.svg',
#                        'id': 2072,
#                        'name': 'England'},
#               'awayTeam': {'crest': 'https://crests.football-data.org/76.svg',
#                            'id': 76,
#                            'name': 'Wolverhampton Wanderers FC',
#                            'shortName': 'Wolverhampton',
#                            'tla': 'WOL'},
#               'competition': {'code': 'PL',
#                               'emblem': 'https://crests.football-data.org/PL.png',
#                               'id': 2021,
#                               'name': 'Premier League',
#                               'type': 'LEAGUE'},
#               'group': None,
#               'homeTeam': {'crest': 'https://crests.football-data.org/66.png',
#                            'id': 66,
#                            'name': 'Manchester United FC',
#                            'shortName': 'Man United',
#                            'tla': 'MUN'},
#               'id': 435952,
#               'lastUpdated': '2024-03-16T10:21:28Z',
#               'matchday': 1,
#               'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve '
#                               'odds.'},
#               'referees': [{'id': 11430,
#                             'name': 'Simon Hooper',
#                             'nationality': 'England',
#                             'type': 'REFEREE'}],
#               'score': {'duration': 'REGULAR',
#                         'fullTime': {'away': 0, 'home': 1},
#                         'halfTime': {'away': 0, 'home': 0},
#                         'winner': 'HOME_TEAM'},
#               'season': {'currentMatchday': 29,
#                          'endDate': '2024-05-19',
#                          'id': 1564,
#                          'startDate': '2023-08-11',
#                          'winner': None},
#               'stage': 'REGULAR_SEASON',
#               'status': 'FINISHED',
#               'utcDate': '2023-08-14T19:00:00Z'}],
#  'resultSet': {'count': 10,
#                'first': '2023-08-11',
#                'last': '2023-08-14',
#                'played': 10}}

# %%
with open("../temp/matches.json", "w") as f_out:
  f_out.write(str(match_list))
